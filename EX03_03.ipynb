# %% [markdown]
# <a href="https://colab.research.google.com/github/FlyFish0203/flyfish/blob/main/EX03_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = 'https://data.moenv.gov.tw/api/v2/aqx_p_432?api_key=9e565f9a-84dd-4e79-9097-d403cae1ea75&limit=1000&sort=ImportDate%20desc&format=CSV'
df = pd.read_csv(url)
df.head()
# Out:
#   sitename county  aqi pollutant    status  so2    co     o3  o3_8hr   pm10  \
# 0       基隆    基隆市   96      懸浮微粒        普通  4.2  0.26   75.0      48   81.0
# 1       汐止    新北市  100      懸浮微粒        普通  3.6  0.25   80.0      43   85.0
# 2       萬里    新北市  110      懸浮微粒  對敏感族群不健康  2.7  0.28   87.0      64  109.0
# 3       新店    新北市  119        臭氧  對敏感族群不健康  1.4  0.42  113.0      59   84.0
# 4       土城    新北市  106      懸浮微粒  對敏感族群不健康  1.6  0.37   98.0      56  109.0
#
#    ...  wind_speed  wind_direc          publishtime  co_8hr pm2.5_avg  \
# 0  ...         1.1         346  2025/04/17 14:00:00     0.3      26.4
# 1  ...           2          63  2025/04/17 14:00:00     0.3      24.9
# 2  ...         2.4          37  2025/04/17 14:00:00     0.2      25.7
# 3  ...         2.2         325  2025/04/17 14:00:00     0.3      23.3
# 4  ...         2.9         328  2025/04/17 14:00:00     0.5      32.2
#
#   pm10_avg so2_avg   longitude   latitude  siteid
# 0     71.0       2  121.760056  25.129167       1
# 1     75.0       2  121.640810  25.066240       2
# 2     97.0       1  121.689881  25.179667       3
# 3     68.0       0  121.537778  24.977222       4
# 4     87.0       1  121.451861  24.982528       5
#
# [5 rows x 24 columns]

# %%
df=df[['sitename', 'county', 'pollutant', 'status', 'aqi']]
df
# Out:
#        sitename county pollutant    status  aqi
# 0            基隆    基隆市      懸浮微粒        普通   96
# 1            汐止    新北市      懸浮微粒        普通  100
# 2            萬里    新北市      懸浮微粒  對敏感族群不健康  110
# 3            新店    新北市        臭氧  對敏感族群不健康  119
# 4            土城    新北市      懸浮微粒  對敏感族群不健康  106
# ..          ...    ...       ...       ...  ...
# 82       屏東（琉球）    屏東縣      懸浮微粒        普通   90
# 83  台中市（和平區消防隊）    臺中市       NaN        良好   43
# 84       新北（樹林）    新北市      懸浮微粒  對敏感族群不健康  102
# 85       臺南（南化）    臺南市       NaN        良好   38
# 86       屏東(枋山)    屏東縣      懸浮微粒        普通   59
#
# [87 rows x 5 columns]

# %%
condition=df['aqi'] > 100
df[condition]
# Out:
#    sitename county pollutant    status  aqi
# 2        萬里    新北市      懸浮微粒  對敏感族群不健康  110
# 3        新店    新北市        臭氧  對敏感族群不健康  119
# 4        土城    新北市      懸浮微粒  對敏感族群不健康  106
# 5        板橋    新北市      懸浮微粒  對敏感族群不健康  104
# 6        新莊    新北市      懸浮微粒  對敏感族群不健康  104
# 7        菜寮    新北市      懸浮微粒  對敏感族群不健康  102
# 8        林口    新北市      懸浮微粒  對敏感族群不健康  107
# 9        淡水    新北市      懸浮微粒  對敏感族群不健康  105
# 10       士林    臺北市      懸浮微粒  對敏感族群不健康  104
# 11       中山    臺北市      懸浮微粒  對敏感族群不健康  103
# 13       古亭    臺北市        臭氧  對敏感族群不健康  107
# 14       松山    臺北市      懸浮微粒  對敏感族群不健康  101
# 15       大同    臺北市      懸浮微粒  對敏感族群不健康  103
# 16       桃園    桃園市      懸浮微粒  對敏感族群不健康  107
# 17       大園    桃園市      懸浮微粒  對敏感族群不健康  109
# 18       觀音    桃園市      懸浮微粒  對敏感族群不健康  106
# 19       平鎮    桃園市      懸浮微粒  對敏感族群不健康  106
# 20       龍潭    桃園市      懸浮微粒  對敏感族群不健康  101
# 21       湖口    新竹縣      懸浮微粒  對敏感族群不健康  106
# 23       新竹    新竹市      懸浮微粒  對敏感族群不健康  102
# 24       頭份    苗栗縣      懸浮微粒  對敏感族群不健康  104
# 25       苗栗    苗栗縣      懸浮微粒  對敏感族群不健康  103
# 28       沙鹿    臺中市      懸浮微粒  對敏感族群不健康  102
# 33       線西    彰化縣      懸浮微粒  對敏感族群不健康  101
# 34       二林    彰化縣      懸浮微粒  對敏感族群不健康  103
# 40       臺西    雲林縣      懸浮微粒  對敏感族群不健康  105
# 62       陽明    臺北市      懸浮微粒  對敏感族群不健康  104
# 65       三重    新北市      懸浮微粒  對敏感族群不健康  106
# 66       中壢    桃園市      懸浮微粒  對敏感族群不健康  107
# 71       馬祖    連江縣      懸浮微粒  對敏感族群不健康  110
# 73       馬公    澎湖縣      懸浮微粒  對敏感族群不健康  105
# 76      富貴角    新北市      懸浮微粒  對敏感族群不健康  108
# 77       大城    彰化縣     細懸浮微粒  對敏感族群不健康  108
# 84   新北（樹林）    新北市      懸浮微粒  對敏感族群不健康  102

# %%
df['pollutant'].unique()
# Out:
# array(['懸浮微粒', '臭氧', '細懸浮微粒', nan], dtype=object)

# %%
condition = df['county']=='高雄市'
df[condition]
# Out:
#    sitename county pollutant status  aqi
# 46       美濃    高雄市      懸浮微粒     普通   58
# 47       橋頭    高雄市      懸浮微粒     普通   64
# 48       仁武    高雄市      懸浮微粒     普通   67
# 49       鳳山    高雄市      懸浮微粒     普通   67
# 50       大寮    高雄市     細懸浮微粒     普通   57
# 51       林園    高雄市      懸浮微粒     普通   63
# 52       楠梓    高雄市      懸浮微粒     普通   89
# 53       左營    高雄市      懸浮微粒     普通   70
# 54       前金    高雄市      懸浮微粒     普通   78
# 55       前鎮    高雄市      懸浮微粒     普通   73
# 56       小港    高雄市      懸浮微粒     普通   67
# 69       復興    高雄市      懸浮微粒     普通   67
# 80   高雄（湖內）    高雄市      懸浮微粒     普通   78

# %%
df.groupby('county')['aqi'].mean().sort_values(ascending=False)
# Out:
# county
# 連江縣    110.000000
# 桃園市    106.000000
# 新北市    105.538462
# 澎湖縣    105.000000
# 臺北市    102.857143
# 新竹縣    102.500000
# 新竹市    102.000000
# 彰化縣     96.200000
# 基隆市     96.000000
# 雲林縣     93.000000
# 苗栗縣     92.333333
# 嘉義縣     91.000000
# 金門縣     90.000000
# 宜蘭縣     85.666667
# 嘉義市     78.000000
# 臺中市     77.333333
# 花蓮縣     74.000000
# 臺南市     70.500000
# 南投縣     70.333333
# 高雄市     69.076923
# 臺東縣     67.500000
# 屏東縣     60.800000
# Name: aqi, dtype: float64
